# %%
import os
import pandas as pd

from ms.config.pipeline_constants import CONF
from ms.utils.navigation import pjoin

# %%
import numpy as np


def collect_results(root_folder):
    records = []

    for target_model in os.listdir(root_folder):
        target_path = os.path.join(root_folder, target_model)
        if not os.path.isdir(target_path):
            continue

        for selector in os.listdir(target_path):
            selector_path = os.path.join(target_path, selector)
            pred_path = os.path.join(selector_path, 'pred')
            if not os.path.exists(pred_path):
                continue

            for metamodel_file in os.listdir(pred_path):
                if not metamodel_file.endswith('.csv'):
                    continue

                metamodel = metamodel_file.replace('.csv', '')
                file_path = os.path.join(pred_path, metamodel_file)

                df = pd.read_csv(file_path, index_col=0)  # rows are metrics

                for metric, row in df.iterrows():
                    fold_data = {'train': [], 'test': []}

                    for col_name, value in row.items():
                        try:
                            fold_type, fold_num = col_name.split('_')
                            if fold_type in fold_data:
                                fold_data[fold_type].append(float(value))
                        except ValueError:
                            continue  # Skip malformed column names

                    # Add original metric
                    for fold_type in ['train', 'test']:
                        values = fold_data[fold_type]
                        if values:
                            values_series = pd.Series(values)
                            records.append({
                                'target_model': target_model,
                                'selector': selector,
                                'metamodel': metamodel,
                                'metric': metric,
                                'fold_type': fold_type,
                                'mean': values_series.mean(),
                                'std': values_series.std()
                            })

                    # If MSE, also compute and append RMSE
                    if metric.lower() == 'mse':
                        for fold_type in ['train', 'test']:
                            rmse_values = [np.sqrt(v) for v in fold_data[fold_type]]
                            if rmse_values:
                                rmse_series = pd.Series(rmse_values)
                                records.append({
                                    'target_model': target_model,
                                    'selector': selector,
                                    'metamodel': metamodel,
                                    'metric': 'rmse',
                                    'fold_type': fold_type,
                                    'mean': rmse_series.mean(),
                                    'std': rmse_series.std()
                                })

    return pd.DataFrame.from_records(records)

# %%
root_folder = pjoin(CONF.results_path, "tabzilla", "raw")  # Replace with your actual path

# %%
results_df = collect_results(root_folder)

# %%
results_df

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_rmse_bars(df, save_dir=None):
     # Filter only RMSE on test folds
    rmse_df = df[(df['metric'] == 'rmse') & (df['fold_type'] == 'test')]

    target_models = sorted(rmse_df['target_model'].unique())
    selectors = sorted(rmse_df['selector'].unique())

    width = 0.1  # width of each bar
    spacing = 0.15  # spacing between groups

    x_indices = np.arange(len(target_models))

    for metamodel in rmse_df['metamodel'].unique():
        sub_df = rmse_df[rmse_df['metamodel'] == metamodel]

        fig, ax = plt.subplots(figsize=(12, 6))

        for i, selector in enumerate(selectors):
            selector_df = sub_df[sub_df['selector'] == selector]
            
            means = []
            stds = []

            # Safely get mean and std for each target_model, skip if not available
            for tm in target_models:
                target_data = selector_df[selector_df['target_model'] == tm]
                if not target_data.empty:
                    means.append(target_data['mean'].values[0])
                    stds.append(target_data['std'].values[0])
                else:
                    # Skip this target_model if data is missing
                    break
            else:  # Only plot if all target_models have data
                offset = (i - len(selectors)/2) * width + width/2
                bar_positions = x_indices + offset
                ax.bar(bar_positions, means, width=width, yerr=stds, label=selector, capsize=4)

        ax.set_xticks(x_indices)
        ax.set_xticklabels(target_models, rotation=45)
        ax.set_xlabel('Target Model')
        ax.set_ylabel('RMSE (mean ± std)')
        ax.set_title(f'RMSE (Test) for Metamodel: {metamodel}')
        ax.legend(title='Selector')
        ax.grid(True, axis='y', linestyle='--', alpha=0.5)

        plt.tight_layout()

        if save_dir:
            plt.savefig(f"{save_dir}/rmse_{metamodel}_matplotlib.png")
        else:
            plt.show()

        plt.close()

# %%
plot_rmse_bars(results_df)

# %%
def aggregate_selected_features(root_dir, normalize_by_min=False):
    """
    Traverse folder structure and return selected features for each selector
    per target model, sorted by mean absolute value across folds.

    Criteria:
    - Selected in >= half the folds (non-NaN).
    - All selected values have same sign.
    - Score = mean of absolute values (across folds).
    - Optionally, reduce all lists to length of smallest list for each target model.

    Args:
        root_dir (str): Root folder path.
        normalize_by_min (bool): Whether to truncate lists to the min number of features per target model.

    Returns:
        dict[target_model][selector] = list of (feature, score), sorted descending.
    """
    results = {}

    for target_model in os.listdir(root_dir):
        target_path = os.path.join(root_dir, target_model)
        if not os.path.isdir(target_path):
            continue

        results[target_model] = {}
        min_len = float('inf')

        for selector in os.listdir(target_path):
            selector_path = os.path.join(target_path, selector)
            data_csv = os.path.join(selector_path, "data.csv")
            if not os.path.isfile(data_csv):
                continue

            df = pd.read_csv(data_csv, index_col=0)
            value_cols = [col for col in df.columns if col.startswith("value_")]
            values = df[value_cols]

            # Selection criteria
            non_nan_counts = values.notna().sum(axis=1)
            min_required = len(value_cols) // 2
            selected_mask = non_nan_counts >= min_required
            filtered = values[selected_mask]

            def has_consistent_sign(row):
                signs = np.sign(row.dropna())
                return np.all(signs > 0) or np.all(signs < 0)

            consistent_mask = filtered.apply(has_consistent_sign, axis=1)
            final_df = filtered[consistent_mask]

            # Scoring and sorting
            feature_scores = final_df.abs().mean(axis=1)
            sorted_features = sorted(feature_scores.items(), key=lambda x: -x[1])

            results[target_model][selector] = sorted_features

            # Track min length if normalization is enabled
            if normalize_by_min:
                min_len = min(min_len, len(sorted_features))
                
        print(f"Target model: {target_model}, Min length: {min_len}")

        # Truncate lists if requested
        if normalize_by_min and min_len < float('inf'):
            for selector in results[target_model]:
                results[target_model][selector] = results[target_model][selector][:min_len]

    return results

# %%
sel_f = aggregate_selected_features(root_folder, True)
# Out:
# Target model: LinearModel, Min length: 16
# Target model: RandomForest, Min length: 21
# Target model: rtdl_FTTransformer, Min length: 10
# Target model: rtdl_MLP, Min length: 14
# Target model: rtdl_ResNet, Min length: 11
# Target model: XGBoost, Min length: 8

# %%
sel_f
# Out:
# {'LinearModel': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.skewness', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.kurtosis.min', 1.0)],
#   'corr': [('f__pymfe.model-based.nodes_per_inst', 0.6277515396426375),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.6265063964555322),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.5733331312172671),
#    ('f__pymfe.statistical.can_cor.min', 0.5599284593849738),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.5409312211762238),
#    ('f__pymfe.statistical.can_cor.mean', 0.5039416840140145),
#    ('f__pymfe.landmarking.one_nn.mean', 0.4789652330611047),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.4366783085821563),
#    ('f__pymfe.info-theory.class_ent', 0.3919248058801683),
#    ('f__pymfe.model-based.nodes_per_attr', 0.37128182111423974),
#    ('f__pymfe.landmarking.elite_nn.mean', 0.35259548629931103),
#    ('f__pymfe.model-based.tree_depth.mean', 0.3339386057913658),
#    ('f__pymfe.landmarking.best_node.mean', 0.329653627177741),
#    ('f__pymfe.model-based.nodes', 0.32767659195069165),
#    ('f__pymfe.landmarking.random_node.min', 0.323215423349797),
#    ('f__pymfe.landmarking.worst_node.mean', 0.3117307759722551)],
#   'f_val': [('f__pymfe.landmarking.naive_bayes.mean', 70.49330847473485),
#    ('f__pymfe.landmarking.linear_discr.mean', 55.041977020217494),
#    ('f__pymfe.model-based.nodes_per_inst', 54.46417197585627),
#    ('f__pymfe.landmarking.naive_bayes.min', 49.94100131574954),
#    ('f__pymfe.statistical.can_cor.min', 44.212975332233555),
#    ('f__pymfe.statistical.can_cor.mean', 32.06938937180122),
#    ('f__pymfe.landmarking.one_nn.mean', 26.772707589125407),
#    ('f__pymfe.model-based.leaves_corrob.max', 24.090351285845095),
#    ('f__pymfe.info-theory.class_ent', 23.30445216324546),
#    ('f__pymfe.landmarking.best_node.mean', 16.773360386337863),
#    ('f__pymfe.landmarking.elite_nn.mean', 15.847621334928101),
#    ('f__pymfe.landmarking.worst_node.mean', 15.80560927602157),
#    ('f__pymfe.landmarking.random_node.min', 15.762079371718514),
#    ('f__pymfe.model-based.tree_depth.mean', 15.748322307297963),
#    ('f__pymfe.general.nr_class', 13.878446435485756),
#    ('f__pymfe.model-based.nodes', 12.586981089387233)],
#   'lasso': [('f__pymfe.info-theory.class_ent', 0.07065135078395465),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.05896637165808414),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.027087255838130396),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.019541009494123802),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.01929333627342872),
#    ('f__pymfe.model-based.nodes_per_inst', 0.019006928653323603),
#    ('f__pymfe.general.nr_attr', 0.01781786541089552),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.017078638631079147),
#    ('f__pymfe.model-based.leaves_per_class.skewness', 0.012134450893702225),
#    ('f__pymfe.statistical.can_cor.mean', 0.011855372577163932),
#    ('f__pymfe.general.nr_bin', 0.011322727842945),
#    ('f__pymfe.statistical.max.min', 0.010760659380229467),
#    ('f__pymfe.general.freq_class.sd', 0.009738198013053234),
#    ('f__pymfe.statistical.gravity', 0.0075093896718553),
#    ('f__pymfe.general.freq_class.min', 0.006892123960198251),
#    ('f__pymfe.landmarking.worst_node.skewness', 0.006772845061250549)],
#   'mi': [('f__pymfe.landmarking.linear_discr.mean', 0.408521893938888),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.40183641944381554),
#    ('f__pymfe.general.freq_class.sd', 0.3571462565791568),
#    ('f__pymfe.model-based.nodes_per_inst', 0.328322814522084),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.30979141420964246),
#    ('f__pymfe.info-theory.class_ent', 0.29217969085148887),
#    ('f__pymfe.statistical.can_cor.mean', 0.2615233240167196),
#    ('f__pymfe.landmarking.best_node.mean', 0.23886148821182007),
#    ('f__pymfe.statistical.can_cor.min', 0.2175782483548682),
#    ('f__pymfe.landmarking.one_nn.mean', 0.20523462041043922),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.1920029340097503),
#    ('f__pymfe.landmarking.random_node.min', 0.1717500109655525),
#    ('f__pymfe.general.freq_class.min', 0.16564716358664255),
#    ('f__pymfe.general.nr_class', 0.16246776391379494),
#    ('f__pymfe.model-based.var_importance.max', 0.15678951377132327),
#    ('f__pymfe.model-based.var_importance.sd', 0.15033755903017967)],
#   'rfe_mlp': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.model-based.var_importance.min', 1.0),
#    ('f__pymfe.model-based.var_importance.sd', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.skewness', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.kurtosis.mean', 1.0),
#    ('f__pymfe.model-based.tree_shape.sd', 1.0),
#    ('f__pymfe.statistical.roy_root', 1.0),
#    ('f__pymfe.statistical.max.min', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.model-based.leaves_per_class.max', 1.0),
#    ('f__pymfe.model-based.nodes_per_attr', 1.0),
#    ('f__pymfe.model-based.nodes_per_inst', 1.0),
#    ('f__pymfe.model-based.var_importance.min', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.model-based.leaves_corrob.kurtosis', 1.0),
#    ('f__pymfe.statistical.roy_root', 1.0),
#    ('f__pymfe.statistical.max.min', 1.0),
#    ('f__pymfe.statistical.mean.kurtosis', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.1332983473522959),
#    ('f__pymfe.general.nr_bin', 0.1299221879957158),
#    ('f__pymfe.model-based.tree_depth.mean', 0.1269137049102144),
#    ('f__pymfe.model-based.tree_shape.mean', 0.12428394221840637),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.11251384806313068),
#    ('f__pymfe.statistical.roy_root', 0.1104812613970244),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.1053431920996692),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.10501450418540387),
#    ('f__pymfe.model-based.nodes_per_inst', 0.0991698239998936),
#    ('f__pymfe.model-based.nodes', 0.09032431606932148),
#    ('f__pymfe.statistical.can_cor.mean', 0.08568706481472327),
#    ('f__pymfe.statistical.can_cor.min', 0.08005778480420259),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.0771794674209378),
#    ('f__pymfe.general.nr_num', 0.077130900461321),
#    ('f__pymfe.landmarking.worst_node.mean', 0.07621270443314529),
#    ('f__pymfe.statistical.nr_outliers', 0.06855867886032085)],
#   'xgb': [('f__pymfe.landmarking.naive_bayes.mean', 0.190173938),
#    ('f__pymfe.model-based.nodes_per_inst', 0.10130131140000001),
#    ('f__pymfe.model-based.tree_depth.mean', 0.09401179488),
#    ('f__pymfe.landmarking.worst_node.mean', 0.06971954265000001),
#    ('f__pymfe.statistical.can_cor.min', 0.0522294052),
#    ('f__pymfe.model-based.nodes_repeated.skewness', 0.0440208005),
#    ('f__pymfe.landmarking.random_node.kurtosis', 0.0411511952515),
#    ('f__pymfe.model-based.nodes_per_level.skewness', 0.04026419590974999),
#    ('f__pymfe.model-based.var_importance.sd', 0.03297726014905),
#    ('f__pymfe.general.freq_class.sd', 0.027990989260000005),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.027099263658460004),
#    ('f__pymfe.info-theory.class_ent', 0.021463429200000002),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.0200015438),
#    ('f__pymfe.general.nr_bin', 0.01576927396),
#    ('f__pymfe.model-based.nodes', 0.012884190819999999),
#    ('f__pymfe.model-based.tree_imbalance.max', 0.011640819713)]},
#  'RandomForest': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.skewness', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.kurtosis.min', 1.0),
#    ('f__pymfe.statistical.cor.mean', 1.0),
#    ('f__pymfe.statistical.cor.max', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0)],
#   'corr': [('f__pymfe.model-based.nodes_per_inst', 0.6234262246732162),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.5883313892541374),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.5330872331390021),
#    ('f__pymfe.statistical.can_cor.min', 0.4986595157068991),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.4924606062176079),
#    ('f__pymfe.landmarking.one_nn.mean', 0.47227755394061255),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.43902942507079434),
#    ('f__pymfe.statistical.can_cor.mean', 0.390608027757773),
#    ('f__pymfe.info-theory.class_ent', 0.39057599255593806),
#    ('f__pymfe.landmarking.best_node.mean', 0.3816131183263219),
#    ('f__pymfe.landmarking.elite_nn.mean', 0.3735635448111782),
#    ('f__pymfe.model-based.tree_depth.mean', 0.3554816891356619),
#    ('f__pymfe.model-based.nodes', 0.35493575700066093),
#    ('f__pymfe.general.nr_class', 0.3506325605068852),
#    ('f__pymfe.model-based.nodes_per_attr', 0.3494870884036532),
#    ('f__pymfe.landmarking.random_node.min', 0.34743067461208926),
#    ('f__pymfe.landmarking.worst_node.mean', 0.3408025151972464),
#    ('f__pymfe.model-based.leaves_per_class.max', 0.34077916868351266),
#    ('f__pymfe.model-based.tree_shape.mean', 0.32789428000542997),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.3177490276643405),
#    ('f__pymfe.model-based.var_importance.max', 0.31653614492502297)],
#   'f_val': [('f__pymfe.landmarking.naive_bayes.mean', 59.85844324533964),
#    ('f__pymfe.model-based.nodes_per_inst', 47.701778807498215),
#    ('f__pymfe.landmarking.naive_bayes.min', 40.30328631921992),
#    ('f__pymfe.landmarking.linear_discr.mean', 37.86673934342405),
#    ('f__pymfe.statistical.can_cor.min', 29.544715960517493),
#    ('f__pymfe.info-theory.class_ent', 27.804871898347308),
#    ('f__pymfe.model-based.leaves_corrob.max', 24.628207587754066),
#    ('f__pymfe.landmarking.one_nn.mean', 23.056309474558212),
#    ('f__pymfe.landmarking.elite_nn.mean', 20.852849259456896),
#    ('f__pymfe.statistical.can_cor.mean', 20.398531230718582),
#    ('f__pymfe.landmarking.best_node.mean', 19.269335465559053),
#    ('f__pymfe.model-based.nodes', 17.51898942311316),
#    ('f__pymfe.general.nr_class', 16.688225489829613),
#    ('f__pymfe.model-based.tree_depth.mean', 16.523362164335246),
#    ('f__pymfe.landmarking.worst_node.mean', 14.520230528921257),
#    ('f__pymfe.general.freq_class.sd', 14.497194359583748),
#    ('f__pymfe.landmarking.random_node.min', 14.193006726933472),
#    ('f__pymfe.model-based.nodes_per_attr', 13.485374471658787),
#    ('f__pymfe.model-based.leaves_per_class.max', 11.6768467050292),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 10.796763107987456),
#    ('f__pymfe.model-based.tree_imbalance.mean', 9.810696405803647)],
#   'lasso': [('f__pymfe.info-theory.class_ent', 0.050921684258852164),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.0357079493499997),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.031290543689232245),
#    ('f__pymfe.model-based.nodes_per_inst', 0.01930682045329512),
#    ('f__pymfe.model-based.nodes', 0.013546237230399619),
#    ('f__pymfe.statistical.gravity', 0.01290608857618438),
#    ('f__pymfe.general.freq_class.sd', 0.011394602718892324),
#    ('f__pymfe.general.freq_class.skewness', 0.010156513927396148),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.009769005308587226),
#    ('f__pymfe.model-based.leaves_per_class.sd', 0.008724750298915234),
#    ('f__pymfe.landmarking.worst_node.kurtosis', 0.00681679703218338),
#    ('f__pymfe.general.nr_bin', 0.0061278354705342),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.00597879153814884),
#    ('f__pymfe.landmarking.one_nn.mean', 0.0055161355138038),
#    ('f__pymfe.model-based.leaves_per_class.skewness', 0.0046786768138585),
#    ('f__pymfe.general.nr_inst', 0.00418370942199775),
#    ('f__pymfe.general.nr_attr', 0.0039242747965361),
#    ('f__pymfe.model-based.leaves_per_class.min', 0.0036788617216430997),
#    ('f__pymfe.statistical.sparsity.max', 0.0019194958838390998),
#    ('f__pymfe.landmarking.worst_node.skewness', 0.0017542917244638748),
#    ('f__pymfe.model-based.nodes_per_level.skewness', 0.0008122350155704578)],
#   'mi': [('f__pymfe.landmarking.naive_bayes.mean', 0.3937129995093697),
#    ('f__pymfe.model-based.nodes_per_inst', 0.37602117681350117),
#    ('f__pymfe.statistical.can_cor.min', 0.298233405611548),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.29655603008076187),
#    ('f__pymfe.info-theory.class_ent', 0.27955770532572244),
#    ('f__pymfe.model-based.var_importance.max', 0.2594740078170362),
#    ('f__pymfe.landmarking.best_node.mean', 0.2224473045119101),
#    ('f__pymfe.statistical.can_cor.mean', 0.21258403036239923),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.20624891221128255),
#    ('f__pymfe.general.freq_class.sd', 0.18676330730352625),
#    ('f__pymfe.model-based.var_importance.sd', 0.18665369292699124),
#    ('f__pymfe.landmarking.one_nn.mean', 0.165180288158295),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.1599917662740538),
#    ('f__pymfe.general.freq_class.min', 0.15752785913926526),
#    ('f__pymfe.landmarking.elite_nn.mean', 0.1527471442771246),
#    ('f__pymfe.statistical.range.kurtosis', 0.14399615517079628),
#    ('f__pymfe.statistical.min.max', 0.12766441397380368),
#    ('f__pymfe.model-based.leaves_per_class.min', 0.1272829178824994),
#    ('f__pymfe.model-based.nodes_repeated.skewness', 0.12723756669160516),
#    ('f__pymfe.statistical.cov.kurtosis', 0.12430635950717508),
#    ('f__pymfe.statistical.eigenvalues.min', 0.12340918450228294)],
#   'rfe_mlp': [('f__pymfe.statistical.max.min', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.max', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.kurtosis.skewness', 1.0),
#    ('f__pymfe.statistical.roy_root', 1.0),
#    ('f__pymfe.statistical.mad.kurtosis', 1.0),
#    ('f__pymfe.statistical.median.skewness', 1.0),
#    ('f__pymfe.statistical.min.kurtosis', 1.0),
#    ('f__pymfe.statistical.min.max', 1.0),
#    ('f__pymfe.statistical.min.mean', 1.0),
#    ('f__pymfe.statistical.min.min', 1.0),
#    ('f__pymfe.statistical.min.skewness', 1.0),
#    ('f__pymfe.statistical.nr_cor_attr', 1.0),
#    ('f__pymfe.statistical.skewness.mean', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_depth.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_depth.mean', 1.0),
#    ('f__pymfe.model-based.leaves_branch.skewness', 1.0),
#    ('f__pymfe.model-based.leaves_corrob.max', 1.0),
#    ('f__pymfe.model-based.leaves_per_class.max', 1.0),
#    ('f__pymfe.model-based.nodes_per_attr', 1.0),
#    ('f__pymfe.model-based.nodes_per_inst', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.max', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.mean', 1.0),
#    ('f__pymfe.model-based.var_importance.max', 1.0),
#    ('f__pymfe.statistical.w_lambda', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.landmarking.worst_node.skewness', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.roy_root', 1.0),
#    ('f__pymfe.statistical.max.min', 1.0),
#    ('f__pymfe.statistical.min.max', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.1179772407840404),
#    ('f__pymfe.general.nr_class', 0.1091670401093051),
#    ('f__pymfe.model-based.nodes', 0.09186822575116016),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.08792780202832029),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.08514806937998824),
#    ('f__pymfe.model-based.tree_depth.mean', 0.0826148160942276),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.07612459909392713),
#    ('f__pymfe.model-based.nodes_per_inst', 0.07562807777974376),
#    ('f__pymfe.statistical.roy_root', 0.0744772528104692),
#    ('f__pymfe.model-based.tree_shape.mean', 0.06697978767665023),
#    ('f__pymfe.landmarking.best_node.mean', 0.0655644482342531),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.05994855592509725),
#    ('f__pymfe.statistical.can_cor.mean', 0.059802292139848896),
#    ('f__pymfe.general.nr_inst', 0.059285329428914346),
#    ('f__pymfe.model-based.var_importance.sd', 0.05758937161005655),
#    ('f__pymfe.statistical.gravity', 0.05529141153437818),
#    ('f__pymfe.model-based.leaves_per_class.max', 0.0547783303047322),
#    ('f__pymfe.landmarking.worst_node.mean', 0.048991871777263704),
#    ('f__pymfe.statistical.can_cor.min', 0.04809874088910521),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.0441726244111678),
#    ('f__pymfe.landmarking.elite_nn.mean', 0.0389671732544284)],
#   'xgb': [('f__pymfe.landmarking.naive_bayes.mean', 0.1249750492),
#    ('f__pymfe.model-based.nodes_per_inst', 0.1130126808),
#    ('f__pymfe.model-based.tree_depth.mean', 0.095120663),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.07265607694000001),
#    ('f__pymfe.landmarking.random_node.sd', 0.0517565085),
#    ('f__pymfe.info-theory.class_ent', 0.0427135742),
#    ('f__pymfe.model-based.nodes', 0.03312529396),
#    ('f__pymfe.statistical.min.mean', 0.02588943691),
#    ('f__pymfe.statistical.min.min', 0.0249485197345),
#    ('f__pymfe.statistical.cor.sd', 0.023141243191750004),
#    ('f__pymfe.statistical.w_lambda', 0.022031889643999998),
#    ('f__pymfe.statistical.mad.min', 0.02055517537),
#    ('f__pymfe.model-based.leaves_per_class.sd', 0.019052509928299998),
#    ('f__pymfe.general.freq_class.sd', 0.0175915031),
#    ('f__pymfe.statistical.can_cor.min', 0.01666261394),
#    ('f__pymfe.general.freq_class.skewness', 0.01601150092),
#    ('f__pymfe.model-based.nodes_repeated.skewness', 0.015903593612),
#    ('f__pymfe.landmarking.best_node.kurtosis', 0.01370366934708),
#    ('f__pymfe.general.nr_bin', 0.012710594672),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.01248140948),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.012301459271999998)]},
#  'rtdl_FTTransformer': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0)],
#   'corr': [('f__pymfe.landmarking.naive_bayes.mean', 0.5241536103522108),
#    ('f__pymfe.model-based.nodes_per_inst', 0.5088215575778094),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.502774053780562),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.389627538016739),
#    ('f__pymfe.statistical.can_cor.min', 0.3857388863703103),
#    ('f__pymfe.landmarking.one_nn.mean', 0.37739786964936295),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.3636482477048019),
#    ('f__pymfe.info-theory.class_ent', 0.35271016007561184),
#    ('f__pymfe.statistical.can_cor.mean', 0.3279387920954643),
#    ('f__pymfe.general.nr_class', 0.31927972184392817)],
#   'f_val': [('f__pymfe.landmarking.naive_bayes.mean', 39.5798467251428),
#    ('f__pymfe.landmarking.naive_bayes.min', 35.143111084974564),
#    ('f__pymfe.model-based.nodes_per_inst', 32.43609876000162),
#    ('f__pymfe.landmarking.linear_discr.mean', 23.285885858163738),
#    ('f__pymfe.info-theory.class_ent', 23.104670270978566),
#    ('f__pymfe.general.nr_class', 19.927471346985016),
#    ('f__pymfe.statistical.can_cor.min', 19.600884915553028),
#    ('f__pymfe.landmarking.one_nn.mean', 14.670456693275943),
#    ('f__pymfe.landmarking.random_node.min', 13.236760412558956),
#    ('f__pymfe.landmarking.elite_nn.mean', 13.079421768722288)],
#   'lasso': [('f__pymfe.info-theory.class_ent', 0.06263815213171207),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.03794463690884532),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.029810793029492903),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.02933284946213872),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.028815467154753374),
#    ('f__pymfe.general.nr_class', 0.0248788504493613),
#    ('f__pymfe.general.freq_class.skewness', 0.020881679183679423),
#    ('f__pymfe.model-based.nodes_per_inst', 0.0192260822045905),
#    ('f__pymfe.general.attr_to_inst', 0.01807041669743084),
#    ('f__pymfe.landmarking.worst_node.skewness', 0.0148150782269031)],
#   'mi': [('f__pymfe.landmarking.naive_bayes.mean', 0.3443262896419591),
#    ('f__pymfe.general.freq_class.sd', 0.3443206738800483),
#    ('f__pymfe.info-theory.class_ent', 0.3123335109747341),
#    ('f__pymfe.model-based.nodes_per_inst', 0.2505841588491574),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.23635446229234716),
#    ('f__pymfe.landmarking.one_nn.mean', 0.20323278077921528),
#    ('f__pymfe.landmarking.elite_nn.mean', 0.20064524021567767),
#    ('f__pymfe.landmarking.best_node.mean', 0.19729419217475247),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.19095714500497865),
#    ('f__pymfe.general.freq_class.min', 0.187242300406563)],
#   'rfe_mlp': [('f__pymfe.general.nr_cat', 1.0),
#    ('f__pymfe.statistical.kurtosis.mean', 1.0),
#    ('f__pymfe.statistical.eigenvalues.kurtosis', 1.0),
#    ('f__pymfe.model-based.var_importance.max', 1.0),
#    ('f__pymfe.statistical.w_lambda', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.max', 1.0),
#    ('f__pymfe.statistical.cor.mean', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.cor.skewness', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.model-based.leaves_per_class.skewness', 1.0),
#    ('f__pymfe.model-based.nodes_per_inst', 1.0),
#    ('f__pymfe.model-based.nodes_per_level.kurtosis', 1.0),
#    ('f__pymfe.model-based.nodes_repeated.skewness', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.16423490217933756),
#    ('f__pymfe.general.nr_class', 0.15503231666064624),
#    ('f__pymfe.model-based.tree_depth.mean', 0.13491256509745164),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.13065835057267644),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.1063389618969323),
#    ('f__pymfe.model-based.var_importance.max', 0.09875451732790617),
#    ('f__pymfe.model-based.nodes_per_inst', 0.09138070654159272),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.08905704333984182),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.0877432738358019),
#    ('f__pymfe.statistical.roy_root', 0.08673599897199806)],
#   'xgb': [('f__pymfe.landmarking.naive_bayes.mean', 0.0922335758),
#    ('f__pymfe.general.freq_class.skewness', 0.07871202740000001),
#    ('f__pymfe.statistical.mean.kurtosis', 0.0710758168466),
#    ('f__pymfe.statistical.can_cor.min', 0.065407108232),
#    ('f__pymfe.statistical.g_mean.mean', 0.055435260962499996),
#    ('f__pymfe.statistical.min.kurtosis', 0.05167597247333333),
#    ('f__pymfe.statistical.range.skewness', 0.044729451838),
#    ('f__pymfe.model-based.leaves_per_class.skewness', 0.0357584422),
#    ('f__pymfe.model-based.nodes_per_level.skewness', 0.035657818333333334),
#    ('f__pymfe.model-based.nodes_per_inst', 0.032780467540000004)]},
#  'rtdl_MLP': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.skewness', 1.0)],
#   'corr': [('f__pymfe.landmarking.naive_bayes.mean', 0.4992879814320076),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.4825176062505571),
#    ('f__pymfe.model-based.nodes_per_inst', 0.4386776264782554),
#    ('f__pymfe.info-theory.class_ent', 0.4259045395726715),
#    ('f__pymfe.landmarking.best_node.mean', 0.3873648769512654),
#    ('f__pymfe.general.nr_class', 0.3863238769152305),
#    ('f__pymfe.statistical.can_cor.min', 0.3832723508553434),
#    ('f__pymfe.landmarking.random_node.min', 0.36098252682000065),
#    ('f__pymfe.landmarking.worst_node.mean', 0.3591248644096073),
#    ('f__pymfe.landmarking.one_nn.mean', 0.3559191578221253),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.35559035096958586),
#    ('f__pymfe.model-based.leaves_per_class.max', 0.3453263017377109),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.3330566400429673),
#    ('f__pymfe.general.freq_class.sd', 0.31457910235561615)],
#   'f_val': [('f__pymfe.info-theory.class_ent', 36.213434278567846),
#    ('f__pymfe.general.nr_class', 31.86908691642609),
#    ('f__pymfe.landmarking.naive_bayes.mean', 23.283464292980305),
#    ('f__pymfe.landmarking.naive_bayes.min', 21.763818961617716),
#    ('f__pymfe.landmarking.random_node.min', 18.772671006879413),
#    ('f__pymfe.landmarking.best_node.mean', 17.494975176420823),
#    ('f__pymfe.model-based.nodes_per_inst', 16.85071201807576),
#    ('f__pymfe.landmarking.worst_node.mean', 16.69962357678629),
#    ('f__pymfe.general.freq_class.sd', 16.30114179433071),
#    ('f__pymfe.model-based.leaves_per_class.max', 15.92722302272264),
#    ('f__pymfe.model-based.leaves_per_class.min', 15.527450012107973),
#    ('f__pymfe.landmarking.elite_nn.mean', 13.273153056988154),
#    ('f__pymfe.statistical.can_cor.min', 11.701075962643177),
#    ('f__pymfe.general.freq_class.skewness', 11.346296255409992)],
#   'lasso': [('f__pymfe.info-theory.class_ent', 0.08616276229851513),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.042364223061164),
#    ('f__pymfe.statistical.min.sd', 0.040114907723584003),
#    ('f__pymfe.general.nr_class', 0.035625593858146724),
#    ('f__pymfe.general.nr_inst', 0.0317249163006366),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.0315793594411989),
#    ('f__pymfe.general.attr_to_inst', 0.029921264632980102),
#    ('f__pymfe.statistical.iq_range.mean', 0.029874187350676686),
#    ('f__pymfe.model-based.leaves_corrob.kurtosis', 0.02724277077865228),
#    ('f__pymfe.statistical.eigenvalues.min', 0.026653069394103876),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.025564310227736402),
#    ('f__pymfe.landmarking.one_nn.mean', 0.023557920332926797),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.0207673729716673),
#    ('f__pymfe.model-based.nodes_per_level.kurtosis', 0.020237432757051203)],
#   'mi': [('f__pymfe.info-theory.class_ent', 0.40946356000574013),
#    ('f__pymfe.general.freq_class.sd', 0.3655643314873619),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.31620107332446884),
#    ('f__pymfe.model-based.nodes_per_inst', 0.24133091877492063),
#    ('f__pymfe.statistical.can_cor.mean', 0.2407705228312583),
#    ('f__pymfe.landmarking.random_node.min', 0.23646973390801102),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.23396367740413013),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.23224674115017457),
#    ('f__pymfe.general.freq_class.min', 0.22607176072274943),
#    ('f__pymfe.landmarking.best_node.mean', 0.20698347273651954),
#    ('f__pymfe.landmarking.one_nn.mean', 0.2023810826046955),
#    ('f__pymfe.statistical.w_lambda', 0.20029710391889122),
#    ('f__pymfe.statistical.min.skewness', 0.19778637750784364),
#    ('f__pymfe.model-based.leaves_per_class.min', 0.18116150171298726)],
#   'rfe_mlp': [('f__pymfe.general.nr_cat', 1.0),
#    ('f__pymfe.statistical.kurtosis.skewness', 1.0),
#    ('f__pymfe.model-based.tree_shape.sd', 1.0),
#    ('f__pymfe.statistical.eigenvalues.kurtosis', 1.0),
#    ('f__pymfe.model-based.var_importance.mean', 1.0),
#    ('f__pymfe.model-based.var_importance.min', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.cor.max', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.kurtosis.mean', 1.0),
#    ('f__pymfe.statistical.roy_root', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.model-based.nodes_per_inst', 1.0),
#    ('f__pymfe.model-based.nodes_per_level.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.max', 1.0),
#    ('f__pymfe.model-based.tree_shape.sd', 1.0),
#    ('f__pymfe.statistical.w_lambda', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.cor.mean', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.kurtosis.min', 1.0),
#    ('f__pymfe.model-based.leaves_per_class.max', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.1485826788463884),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.1482330639921393),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.10836833049993155),
#    ('f__pymfe.model-based.var_importance.max', 0.10248266282470991),
#    ('f__pymfe.model-based.tree_depth.mean', 0.10058404115672424),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.09661779143513795),
#    ('f__pymfe.statistical.min.sd', 0.09379066296199319),
#    ('f__pymfe.statistical.cor.min', 0.09320000852992344),
#    ('f__pymfe.statistical.eigenvalues.kurtosis', 0.089082312146047),
#    ('f__pymfe.statistical.g_mean.mean', 0.08836583312714855),
#    ('f__pymfe.statistical.kurtosis.mean', 0.08824138262159975),
#    ('f__pymfe.model-based.nodes_per_inst', 0.08524585693429804),
#    ('f__pymfe.statistical.sparsity.sd', 0.0789857447545016),
#    ('f__pymfe.model-based.nodes_per_level.kurtosis', 0.078656625310749)],
#   'xgb': [('f__pymfe.statistical.gravity', 0.166868619),
#    ('f__pymfe.statistical.mean.mean', 0.117417291738),
#    ('f__pymfe.model-based.nodes_per_inst', 0.06023197250000001),
#    ('f__pymfe.statistical.iq_range.mean', 0.05604172985),
#    ('f__pymfe.info-theory.class_ent', 0.050431951600000004),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.047091905340000004),
#    ('f__pymfe.model-based.tree_depth.kurtosis', 0.04437049514904),
#    ('f__pymfe.statistical.can_cor.mean', 0.0420400266),
#    ('f__pymfe.statistical.nr_outliers', 0.038428829418025),
#    ('f__pymfe.statistical.can_cor.min', 0.032695679677500006),
#    ('f__pymfe.statistical.mad.min', 0.0304303525),
#    ('f__pymfe.statistical.mean.skewness', 0.029714281586250002),
#    ('f__pymfe.statistical.w_lambda', 0.026577686839999996),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 0.026506380429999997)]},
#  'rtdl_ResNet': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0),
#    ('f__pymfe.statistical.g_mean.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0)],
#   'corr': [('f__pymfe.model-based.nodes_per_inst', 0.5512884525841272),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.5211768981592917),
#    ('f__pymfe.landmarking.one_nn.mean', 0.5163891959781675),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.5121768673449711),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.46822301432738583),
#    ('f__pymfe.statistical.can_cor.mean', 0.39078790168273675),
#    ('f__pymfe.statistical.w_lambda', 0.37128979760193437),
#    ('f__pymfe.landmarking.one_nn.skewness', 0.35308095516809557),
#    ('f__pymfe.statistical.can_cor.min', 0.35260039459821074),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.351035205326608),
#    ('f__pymfe.statistical.roy_root', 0.3439699232034777)],
#   'f_val': [('f__pymfe.landmarking.naive_bayes.mean', 40.80148717301574),
#    ('f__pymfe.landmarking.naive_bayes.min', 39.502323441888045),
#    ('f__pymfe.model-based.nodes_per_inst', 38.208868753849615),
#    ('f__pymfe.landmarking.linear_discr.mean', 34.62465553495673),
#    ('f__pymfe.landmarking.one_nn.mean', 27.445304278267066),
#    ('f__pymfe.statistical.can_cor.mean', 21.516050134463764),
#    ('f__pymfe.statistical.can_cor.min', 15.21725555698735),
#    ('f__pymfe.model-based.leaves_corrob.max', 12.148784006394175),
#    ('f__pymfe.statistical.w_lambda', 9.31060930154554),
#    ('f__pymfe.statistical.sparsity.sd', 7.9428458015855306),
#    ('f__pymfe.info-theory.class_ent', 6.999036423976221)],
#   'lasso': [('f__pymfe.landmarking.naive_bayes.mean', 0.03191081951445822),
#    ('f__pymfe.general.freq_class.sd', 0.027735423214276623),
#    ('f__pymfe.general.nr_inst', 0.023910764801769978),
#    ('f__pymfe.general.attr_to_inst', 0.02373682696602755),
#    ('f__pymfe.statistical.nr_norm', 0.0218148892520946),
#    ('f__pymfe.landmarking.one_nn.mean', 0.020133096351792175),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.0200100733581151),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.01911763143095695),
#    ('f__pymfe.statistical.g_mean.mean', 0.019112666155211417),
#    ('f__pymfe.statistical.sparsity.kurtosis', 0.01777609619392076),
#    ('f__pymfe.landmarking.worst_node.skewness', 0.016438460126260122)],
#   'mi': [('f__pymfe.landmarking.one_nn.mean', 0.33402696711089075),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.30974136997727186),
#    ('f__pymfe.model-based.nodes_per_inst', 0.2982640712286214),
#    ('f__pymfe.statistical.can_cor.min', 0.26908197918146864),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.26906667757814057),
#    ('f__pymfe.statistical.can_cor.mean', 0.24616618150915454),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.21202782125468186),
#    ('f__pymfe.general.freq_class.sd', 0.19963051935450327),
#    ('f__pymfe.info-theory.class_ent', 0.1938840193437535),
#    ('f__pymfe.landmarking.best_node.mean', 0.17757052130344725),
#    ('f__pymfe.model-based.var_importance.max', 0.17227677731672367)],
#   'rfe_mlp': [('f__pymfe.info-theory.class_ent', 1.0),
#    ('f__pymfe.statistical.range.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.cov.min', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.kurtosis.min', 1.0),
#    ('f__pymfe.model-based.nodes_per_level.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.kurtosis', 1.0),
#    ('f__pymfe.model-based.var_importance.min', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.cor.max', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.cov.kurtosis', 1.0),
#    ('f__pymfe.statistical.eigenvalues.min', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.0818746494028425),
#    ('f__pymfe.model-based.tree_shape.mean', 0.08014265403880254),
#    ('f__pymfe.model-based.tree_depth.mean', 0.0801119875895911),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.07927529653689293),
#    ('f__pymfe.general.nr_inst', 0.07912817007909195),
#    ('f__pymfe.statistical.roy_root', 0.07872867619552243),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.0695190487715628),
#    ('f__pymfe.general.nr_num', 0.06814912310032979),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.0665068834094608),
#    ('f__pymfe.statistical.w_lambda', 0.06538410377871047),
#    ('f__pymfe.model-based.nodes', 0.06115093484914772)],
#   'xgb': [('f__pymfe.landmarking.naive_bayes.mean', 0.17823505518),
#    ('f__pymfe.model-based.nodes_per_inst', 0.086284675),
#    ('f__pymfe.statistical.g_mean.mean', 0.0617811866),
#    ('f__pymfe.statistical.can_cor.mean', 0.05359354345),
#    ('f__pymfe.statistical.w_lambda', 0.040184419425),
#    ('f__pymfe.landmarking.one_nn.mean', 0.03768229419),
#    ('f__pymfe.general.nr_inst', 0.0355495402),
#    ('f__pymfe.statistical.skewness.min', 0.027035351712500003),
#    ('f__pymfe.landmarking.naive_bayes.skewness', 0.0266132387932),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.0265394918),
#    ('f__pymfe.statistical.iq_range.mean', 0.024373788881200002)]},
#  'XGBoost': {'base': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.kurtosis.kurtosis', 1.0),
#    ('f__pymfe.statistical.iq_range.skewness', 1.0),
#    ('f__pymfe.statistical.mad.min', 1.0),
#    ('f__pymfe.statistical.mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0),
#    ('f__pymfe.statistical.gravity', 1.0)],
#   'corr': [('f__pymfe.model-based.nodes_per_inst', 0.6049777839741911),
#    ('f__pymfe.landmarking.one_nn.mean', 0.48243107486017694),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.47781793947110884),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.45772070414380706),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.3916365724583808),
#    ('f__pymfe.model-based.leaves_corrob.max', 0.36455743821039477),
#    ('f__pymfe.statistical.can_cor.min', 0.3477397233743866),
#    ('f__pymfe.statistical.can_cor.mean', 0.3436326647478306)],
#   'f_val': [('f__pymfe.model-based.nodes_per_inst', 42.33568632683567),
#    ('f__pymfe.landmarking.naive_bayes.mean', 30.490452225012824),
#    ('f__pymfe.landmarking.naive_bayes.min', 30.057542906648195),
#    ('f__pymfe.landmarking.linear_discr.mean', 25.25362953937079),
#    ('f__pymfe.landmarking.one_nn.mean', 24.125126661548713),
#    ('f__pymfe.statistical.can_cor.mean', 16.22741248846823),
#    ('f__pymfe.statistical.can_cor.min', 13.630829409606514),
#    ('f__pymfe.model-based.leaves_corrob.max', 12.39785184024593)],
#   'lasso': [('f__pymfe.model-based.nodes_per_inst', 0.02369389716454092),
#    ('f__pymfe.general.nr_inst', 0.021562779962551678),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.021509895809120258),
#    ('f__pymfe.general.freq_class.sd', 0.02038647175634582),
#    ('f__pymfe.landmarking.one_nn.mean', 0.01609034878221035),
#    ('f__pymfe.model-based.nodes', 0.0159408876797285),
#    ('f__pymfe.general.attr_to_inst', 0.01542110225032825),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.015315557117676902)],
#   'mi': [('f__pymfe.model-based.nodes_per_inst', 0.4820598921165485),
#    ('f__pymfe.landmarking.one_nn.mean', 0.3126869035346752),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.2985875291839612),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.24257802406195356),
#    ('f__pymfe.statistical.can_cor.mean', 0.24200987853847708),
#    ('f__pymfe.statistical.can_cor.min', 0.20703067835597272),
#    ('f__pymfe.statistical.gravity', 0.18770615621508005),
#    ('f__pymfe.landmarking.naive_bayes.min', 0.1844012127911309)],
#   'rfe_mlp': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.mad.kurtosis', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.mean', 1.0),
#    ('f__pymfe.statistical.cor.kurtosis', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0),
#    ('f__pymfe.statistical.cor.sd', 1.0),
#    ('f__pymfe.statistical.g_mean.mean', 1.0),
#    ('f__pymfe.statistical.iq_range.mean', 1.0)],
#   'rfe_xgb': [('f__pymfe.general.attr_to_inst', 1.0),
#    ('f__pymfe.statistical.kurtosis.mean', 1.0),
#    ('f__pymfe.model-based.tree_imbalance.mean', 1.0),
#    ('f__pymfe.model-based.var_importance.min', 1.0),
#    ('f__pymfe.statistical.w_lambda', 1.0),
#    ('f__pymfe.statistical.can_cor.mean', 1.0),
#    ('f__pymfe.statistical.can_cor.min', 1.0),
#    ('f__pymfe.statistical.cor.min', 1.0)],
#   'te': [('f__pymfe.info-theory.class_ent', 0.07641338878866302),
#    ('f__pymfe.landmarking.linear_discr.mean', 0.06379373997736518),
#    ('f__pymfe.model-based.nodes_per_inst', 0.06135344392831492),
#    ('f__pymfe.statistical.roy_root', 0.058375517589771476),
#    ('f__pymfe.model-based.tree_depth.mean', 0.05677101307417911),
#    ('f__pymfe.model-based.tree_imbalance.mean', 0.054596095987962834),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.05410861674370904),
#    ('f__pymfe.model-based.tree_shape.mean', 0.05210266657949969)],
#   'xgb': [('f__pymfe.model-based.nodes_per_inst', 0.09292047680000001),
#    ('f__pymfe.statistical.min.skewness', 0.07488999),
#    ('f__pymfe.statistical.g_mean.mean', 0.06212569618975),
#    ('f__pymfe.statistical.min.mean', 0.0517104318175),
#    ('f__pymfe.landmarking.random_node.min', 0.04618979574999999),
#    ('f__pymfe.model-based.tree_depth.mean', 0.0441920772825),
#    ('f__pymfe.landmarking.naive_bayes.mean', 0.04099042399799999),
#    ('f__pymfe.landmarking.naive_bayes.sd', 0.0390516115034)]}}
